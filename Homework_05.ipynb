# %% [markdown]
# # **Week 5: Feature Selection and Regularization on the Ames Housing Dataset**
#
# In last week’s homework, you built and evaluated linear regression models with increasingly rich feature sets. This week, we take the next critical step: **deciding which features to keep—and how much complexity is too much**.
#
# In real-world modeling, adding more predictors does not automatically lead to better models. Extra features can increase variance, reduce interpretability, and hurt generalization. This homework explores two complementary strategies for controlling model complexity:
#
# * **Feature selection**, where we explicitly choose a subset of predictors
# * **Regularization**, where we keep all predictors but constrain their influence
#
# Specifically, you will experiment with:
#
# * **Forward Selection**
# * **Backward Selection**
# * **Ridge Regression**
#
# Forward and backward selection approach the same problem from opposite directions—one builds a model up feature by feature, while the other prunes features away—and because both are greedy algorithms, they may arrive at different solutions. In contrast, ridge regression does not discard features at all; instead, it keeps all predictors but shrinks their coefficients toward zero, reducing model complexity in a continuous rather than discrete way.
#
# Comparing these methods highlights an important modeling choice: whether to simplify a model by selecting features explicitly or by regularizing their influence, and how these different strategies affect generalization performance.
#
# There are **4 problems** with **8 graded answers** worth **6 points each**, and you receive **7 points for completion**.

# %%
# Useful imports

import os
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import io
import zipfile

from sklearn.model_selection   import train_test_split, cross_val_score,RepeatedKFold
from sklearn.linear_model      import LinearRegression,Ridge,Lasso
from sklearn.model_selection   import GridSearchCV
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.metrics           import mean_squared_error, r2_score
from sklearn.preprocessing     import StandardScaler 

random_seed = 42

# %% [markdown]
# ## **Prelude: Download the Preprocessed Ames Housing Dataset**
#
# I have stored the dataset as a zipped directory containing the following four files from an 80%-20% split of the Ames dataset after preprocessing (as done in the last homework):
#
# - `X_train.csv`
# - `y_train.csv`
# - `X_test.csv`
# - `y_test.csv`
#
# **TODO:** Run the following cell to download and extract the dataset into the current working directory of this notebook.
# Alternatively, you can manually download the zip file from the provided URL, extract it, and place the files in the same directory as your notebook.
#
# > ⚠️ **Important:**
# > DO NOT use your own version of these datasets from the last homework. The autograder expects the exact split provided in my files for both training and testing sets. Using any other split will result in incorrect results during grading.

# %%
# Download the Ames Housing Dataset from Snyder's web site

# URL to the zip file
zip_url = "https://www.cs.bu.edu/fac/snyder/cs505/Data/ames_housing.zip"

try:
    response = requests.get(zip_url)
    response.raise_for_status()  # Raise an error for bad status codes
    with zipfile.ZipFile(io.BytesIO(response.content)) as zipf:
        zipf.extractall("Ames_Dataset_HW")
    print("Files downloaded and extracted successfully.")
except requests.exceptions.RequestException as e:
    print(f"Error downloading the file: {e}")

# Load the datasets
X_train = pd.read_csv("Ames_Dataset_HW/X_train.csv")
X_test = pd.read_csv("Ames_Dataset_HW/X_test.csv")
y_train = pd.read_csv("Ames_Dataset_HW/y_train.csv").squeeze("columns")          # converted to a Series
y_test = pd.read_csv("Ames_Dataset_HW/y_test.csv").squeeze("columns")

print("Training and testing datasets loaded successfully.")
# Out:
# Files downloaded and extracted successfully.
# Training and testing datasets loaded successfully.

# %% [markdown]
# ## **Problem One: Forward Selection with the Ames Dataset**
#
# For our first experiment we will apply the forward feature selection algorithm to the dataset. Follow these steps, using the notebook from this week's video lesson as a resource as necessary.
#
# **If you have not looked at the video yet, please do it now before continuing.**
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `forward_feature_selection` algorithm from the video notebook for you to use.
#
# 2. **Copy** from the video notebook into the cell indicated below the code that runs forward feature selection and generates a plot (excluding the part that prints the test MSE--we'll do that at the end of this homework). Or write your own version!
#
# 3. **Modify** this code to display the **Root Mean Squared Error (RMSE)** instead of MSE.
#    - *Remember*: RMSE is the square root of MSE, which provides results in dollars rather than dollars squared, making the metric more interpretable.
#    - Both the plot of RMSE vs. the number of selected features and the printout of the Best CV Score should use RMSE.
#
# 4. **Run** the code on `X_train` and `y_train` (keeping all default settings) to:
#    - Generate the plot of **Root Mean Squared Error (RMSE)** vs. **Features Added**, and
#    - Print the **Best Feature Set** found and the **Best CV RMSE Score**.
#
# **Hints:**
# - The feature names will be more legible if you increase the size of the plot and change the angle and size of the xticks, e.g.,
#
#         plt.xticks(range(1, len(selected_features_forward) + 1), selected_features_forward, rotation=60, ha='right', fontsize=6)
#
# - You may wish to change the scale of the y-axis to better see the behavior around the minimum point.

# %%
# Forward Feature Selection

def forward_feature_selection(X, y, model, 
                              scoring='neg_mean_squared_error', 
                              cv = 5, 
                              tol=None,               # None = no delta cutoff
                                                      # use 0.0 for "no further improvements"
                                                      # and 1e-4 for "point of diminishing returns"                                      
                              max_features=None,      # None = use all features
                              n_jobs=-1,
                              verbose=False
                             ):
    selected_features = []                            # List to store the order of features selected
    remaining_features = list(X.columns)              # Features not yet selected
    best_scores = []                                  # List to store the CV score after each feature addition
    previous_score = float('inf')                     # Initialize previous score for improvement comparison

    # Track the best subset of features and its corresponding score
    
    best_feature_set = None                           # Best combination of features found so far
    best_score = float('inf')                         # Best CV score observed so far
    
    while remaining_features:
        scores = {}                                   # Dictionary to hold CV scores for each candidate feature
        for feature in remaining_features:
            current_features = selected_features + [feature]
            
            # Compute the CV score for the current set of features (negated MSE, so lower is better)
            cv_score = -cross_val_score(model, X[current_features], y, 
                                        scoring=scoring, cv=cv, n_jobs=n_jobs
                                       ).mean()
            scores[feature] = cv_score

        # Select the feature that minimizes the CV score
        best_feature = min(scores, key=scores.get)
        current_score = scores[best_feature]
            
        # Check if the improvement is significant based on the tolerance (tol)
        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        # Add the best feature to the selected list and update score trackers
        selected_features.append(best_feature)
        best_scores.append(current_score)
        remaining_features.remove(best_feature)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features[-3:]}, CV Score (MSE): {current_score:.4f}")
        
        # Update the best subset if the current score is better than the best so far
        if current_score < best_score:
            best_score = current_score
            best_feature_set = selected_features.copy()
        
        # Check if the maximum number of features has been reached
        if max_features is not None and len(selected_features) >= max_features:
            break

    return (
        selected_features,      # List of features in the order they were selected (this will be ALL features if max_features == None
        best_scores,            # List of cross-validation scores corresponding to each addition in the previous list
        best_feature_set,       # The subset of features that achieved the best CV score.
        best_score              # The best CV score
    )

# %%
# Your code here:  Run Forward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV Score found. 
# Forward Feature Selection

def forward_feature_selection(X, y, model, 
                              scoring='neg_mean_squared_error', 
                              cv = 5, 
                              tol=None,               # None = no delta cutoff
                                                      # use 0.0 for "no further improvements"
                                                      # and 1e-4 for "point of diminishing returns"                                      
                              max_features=None,      # None = use all features
                              n_jobs=-1,
                              verbose=False
                             ):
    selected_features = []                            # List to store the order of features selected
    remaining_features = list(X.columns)              # Features not yet selected
    best_scores = []                                  # List to store the CV score after each feature addition
    previous_score = float('inf')                     # Initialize previous score for improvement comparison

    # Track the best subset of features and its corresponding score
    
    best_feature_set = None                           # Best combination of features found so far
    best_score = float('inf')                         # Best CV score observed so far
    
    while remaining_features:
        scores = {}                                   # Dictionary to hold CV scores for each candidate feature
        for feature in remaining_features:
            current_features = selected_features + [feature]
            
            # Compute the CV score for the current set of features (negated MSE, so lower is better)
            cv_score = np.sqrt(-cross_val_score(model, X[current_features], y, 
                                        scoring=scoring, cv=cv, n_jobs=n_jobs
                                       ).mean())
            scores[feature] = cv_score

        # Select the feature that minimizes the CV score
        best_feature = min(scores, key=scores.get)
        current_score = scores[best_feature]
            
        # Check if the improvement is significant based on the tolerance (tol)
        if tol is not None and previous_score - current_score < tol:
            if verbose:
                print("Stopping early due to minimal improvement.")
            break

        # Add the best feature to the selected list and update score trackers
        selected_features.append(best_feature)
        best_scores.append(current_score)
        remaining_features.remove(best_feature)
        previous_score = current_score

        if verbose:
            print(f"\nFeatures: {selected_features[-3:]}, CV Score (RMSE): {current_score:.4f}")
        
        # Update the best subset if the current score is better than the best so far
        if current_score < best_score:
            best_score = current_score
            best_feature_set = selected_features.copy()
        
        # Check if the maximum number of features has been reached
        if max_features is not None and len(selected_features) >= max_features:
            break

    return (
        selected_features,      # List of features in the order they were selected (this will be ALL features if max_features == None
        best_scores,            # List of cross-validation scores corresponding to each addition in the previous list
        best_feature_set,       # The subset of features that achieved the best CV score.
        best_score              # The best CV score
    )

# %%
model = LinearRegression()
selected_features, best_scores, best_feature_set, best_score = forward_feature_selection(
    X_train, y_train, model, verbose=True
)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(best_scores) + 1), best_scores, marker='o')
plt.xlabel('Features Added')
plt.ylabel('CV Score (RMSE)')
plt.title('Forward Feature Selection: CV Score vs. Number of Features')
plt.grid()
plt.show()
print(f"Best Feature Set: {best_feature_set}")
print(f"Best CV Score (RMSE): {best_score:.4f}")
# Out:
# Features: ['Overall Qual'], CV Score (RMSE): 46802.2075
#
# Features: ['Overall Qual', 'Gr Liv Area'], CV Score (RMSE): 40431.5679
#
# Features: ['Overall Qual', 'Gr Liv Area', 'BsmtFin SF 1'], CV Score (RMSE): 37835.3641
#
# Features: ['Gr Liv Area', 'BsmtFin SF 1', 'Exter Qual'], CV Score (RMSE): 36098.7651
#
# Features: ['BsmtFin SF 1', 'Exter Qual', 'Garage Cars'], CV Score (RMSE): 34870.1870
#
# Features: ['Exter Qual', 'Garage Cars', 'MS SubClass'], CV Score (RMSE): 33927.1628
#
# Features: ['Garage Cars', 'MS SubClass', 'Bsmt Exposure'], CV Score (RMSE): 33295.2585
#
# Features: ['MS SubClass', 'Bsmt Exposure', 'Kitchen Qual'], CV Score (RMSE): 32840.5474
#
# Features: ['Bsmt Exposure', 'Kitchen Qual', 'Year Built'], CV Score (RMSE): 32468.7439
#
# Features: ['Kitchen Qual', 'Year Built', 'Overall Cond'], CV Score (RMSE): 32150.3461
#
# Features: ['Year Built', 'Overall Cond', 'Screen Porch'], CV Score (RMSE): 31890.8422
#
# Features: ['Overall Cond', 'Screen Porch', 'Lot Area'], CV Score (RMSE): 31655.5954
#
# Features: ['Screen Porch', 'Lot Area', 'Bsmt Qual'], CV Score (RMSE): 31416.9804
#
# Features: ['Lot Area', 'Bsmt Qual', 'Mas Vnr Area'], CV Score (RMSE): 31253.1292
#
# Features: ['Bsmt Qual', 'Mas Vnr Area', 'Bsmt Full Bath'], CV Score (RMSE): 31128.1919
#
# Features: ['Mas Vnr Area', 'Bsmt Full Bath', 'Sale Condition'], CV Score (RMSE): 31011.6138
#
# Features: ['Bsmt Full Bath', 'Sale Condition', 'Fireplaces'], CV Score (RMSE): 30916.7807
#
# Features: ['Sale Condition', 'Fireplaces', 'Functional'], CV Score (RMSE): 30810.0767
#
# Features: ['Fireplaces', 'Functional', 'Yr Sold'], CV Score (RMSE): 30738.5547
#
# Features: ['Functional', 'Yr Sold', 'Neighborhood'], CV Score (RMSE): 30675.1708
#
# Features: ['Yr Sold', 'Neighborhood', 'Wood Deck SF'], CV Score (RMSE): 30621.7095
#
# Features: ['Neighborhood', 'Wood Deck SF', 'House Style'], CV Score (RMSE): 30570.1221
#
# Features: ['Wood Deck SF', 'House Style', 'Kitchen AbvGr'], CV Score (RMSE): 30526.2231
#
# Features: ['House Style', 'Kitchen AbvGr', 'Street'], CV Score (RMSE): 30481.3889
#
# Features: ['Kitchen AbvGr', 'Street', 'Roof Style'], CV Score (RMSE): 30455.8126
#
# Features: ['Street', 'Roof Style', 'Heating QC'], CV Score (RMSE): 30436.3344
#
# Features: ['Roof Style', 'Heating QC', 'Exterior 1st'], CV Score (RMSE): 30403.0880
#
# Features: ['Heating QC', 'Exterior 1st', 'Garage Cond'], CV Score (RMSE): 30392.1320
#
# Features: ['Exterior 1st', 'Garage Cond', 'Bldg Type'], CV Score (RMSE): 30381.2309
#
# Features: ['Garage Cond', 'Bldg Type', 'Land Slope'], CV Score (RMSE): 30369.4951
#
# Features: ['Bldg Type', 'Land Slope', 'Land Contour'], CV Score (RMSE): 30355.6458
#
# Features: ['Land Slope', 'Land Contour', 'Enclosed Porch'], CV Score (RMSE): 30349.0861
#
# Features: ['Land Contour', 'Enclosed Porch', 'Low Qual Fin SF'], CV Score (RMSE): 30342.7090
#
# Features: ['Enclosed Porch', 'Low Qual Fin SF', 'BsmtFin Type 1'], CV Score (RMSE): 30337.1140
#
# Features: ['Low Qual Fin SF', 'BsmtFin Type 1', 'Exterior 2nd'], CV Score (RMSE): 30331.8116
#
# Features: ['BsmtFin Type 1', 'Exterior 2nd', 'Garage Yr Blt'], CV Score (RMSE): 30326.5862
#
# Features: ['Exterior 2nd', 'Garage Yr Blt', 'Garage Qual'], CV Score (RMSE): 30318.6332
#
# Features: ['Garage Yr Blt', 'Garage Qual', 'Lot Shape'], CV Score (RMSE): 30315.4765
#
# Features: ['Garage Qual', 'Lot Shape', 'Half Bath'], CV Score (RMSE): 30314.5352
#
# Features: ['Lot Shape', 'Half Bath', 'MS Zoning'], CV Score (RMSE): 30313.4342
#
# Features: ['Half Bath', 'MS Zoning', 'Exter Cond'], CV Score (RMSE): 30312.7016
#
# Features: ['MS Zoning', 'Exter Cond', 'Bsmt Cond'], CV Score (RMSE): 30314.5833
#
# Features: ['Exter Cond', 'Bsmt Cond', 'Sale Type'], CV Score (RMSE): 30317.4672
#
# Features: ['Bsmt Cond', 'Sale Type', 'Garage Type'], CV Score (RMSE): 30322.1914
#
# Features: ['Sale Type', 'Garage Type', 'Electrical'], CV Score (RMSE): 30327.5329
#
# Features: ['Garage Type', 'Electrical', 'Paved Drive'], CV Score (RMSE): 30333.2901
#
# Features: ['Electrical', 'Paved Drive', 'BsmtFin SF 2'], CV Score (RMSE): 30341.2832
#
# Features: ['Paved Drive', 'BsmtFin SF 2', 'Central Air'], CV Score (RMSE): 30349.7842
#
# Features: ['BsmtFin SF 2', 'Central Air', 'Year Remod/Add'], CV Score (RMSE): 30358.8134
#
# Features: ['Central Air', 'Year Remod/Add', 'Lot Config'], CV Score (RMSE): 30369.5090
#
# Features: ['Year Remod/Add', 'Lot Config', 'Condition 1'], CV Score (RMSE): 30379.7564
#
# Features: ['Lot Config', 'Condition 1', '3Ssn Porch'], CV Score (RMSE): 30394.6068
#
# Features: ['Condition 1', '3Ssn Porch', 'Foundation'], CV Score (RMSE): 30409.5480
#
# Features: ['3Ssn Porch', 'Foundation', 'Condition 2'], CV Score (RMSE): 30424.9758
#
# Features: ['Foundation', 'Condition 2', 'Mo Sold'], CV Score (RMSE): 30440.4924
#
# Features: ['Condition 2', 'Mo Sold', 'TotRms AbvGrd'], CV Score (RMSE): 30459.2464
#
# Features: ['Mo Sold', 'TotRms AbvGrd', 'BsmtFin Type 2'], CV Score (RMSE): 30478.4369
#
# Features: ['TotRms AbvGrd', 'BsmtFin Type 2', 'Heating'], CV Score (RMSE): 30500.7804
#
# Features: ['BsmtFin Type 2', 'Heating', 'Garage Finish'], CV Score (RMSE): 30524.8672
#
# Features: ['Heating', 'Garage Finish', 'Open Porch SF'], CV Score (RMSE): 30556.2496
#
# Features: ['Garage Finish', 'Open Porch SF', '2nd Flr SF'], CV Score (RMSE): 30589.3628
#
# Features: ['Open Porch SF', '2nd Flr SF', '1st Flr SF'], CV Score (RMSE): 30589.3628
#
# Features: ['2nd Flr SF', '1st Flr SF', 'Full Bath'], CV Score (RMSE): 30616.8828
#
# Features: ['1st Flr SF', 'Full Bath', 'Utilities'], CV Score (RMSE): 30650.4651
#
# Features: ['Full Bath', 'Utilities', 'Bsmt Half Bath'], CV Score (RMSE): 30685.1965
#
# Features: ['Utilities', 'Bsmt Half Bath', 'Roof Matl'], CV Score (RMSE): 30716.8479
#
# Features: ['Bsmt Half Bath', 'Roof Matl', 'Bedroom AbvGr'], CV Score (RMSE): 30766.6422
#
# Features: ['Roof Matl', 'Bedroom AbvGr', 'Lot Frontage'], CV Score (RMSE): 30825.8620
#
# Features: ['Bedroom AbvGr', 'Lot Frontage', 'Garage Area'], CV Score (RMSE): 30871.6455
#
# Features: ['Lot Frontage', 'Garage Area', 'Pool Area'], CV Score (RMSE): 30928.8977
#
# Features: ['Garage Area', 'Pool Area', 'Total Bsmt SF'], CV Score (RMSE): 31158.3803
#
# Features: ['Pool Area', 'Total Bsmt SF', 'Bsmt Unf SF'], CV Score (RMSE): 31158.7992
#
# Features: ['Total Bsmt SF', 'Bsmt Unf SF', 'Misc Val'], CV Score (RMSE): 31485.4127
# Best Feature Set: ['Overall Qual', 'Gr Liv Area', 'BsmtFin SF 1', 'Exter Qual', 'Garage Cars', 'MS SubClass', 'Bsmt Exposure', 'Kitchen Qual', 'Year Built', 'Overall Cond', 'Screen Porch', 'Lot Area', 'Bsmt Qual', 'Mas Vnr Area', 'Bsmt Full Bath', 'Sale Condition', 'Fireplaces', 'Functional', 'Yr Sold', 'Neighborhood', 'Wood Deck SF', 'House Style', 'Kitchen AbvGr', 'Street', 'Roof Style', 'Heating QC', 'Exterior 1st', 'Garage Cond', 'Bldg Type', 'Land Slope', 'Land Contour', 'Enclosed Porch', 'Low Qual Fin SF', 'BsmtFin Type 1', 'Exterior 2nd', 'Garage Yr Blt', 'Garage Qual', 'Lot Shape', 'Half Bath', 'MS Zoning', 'Exter Cond']
# Best CV Score (RMSE): 30312.7016

# %% [markdown]
# ### Problem One Graded Questions
#
# Assign `a1a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1a = len(best_feature_set)                    # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1a = {a1a}")
# Out:
# a1a = 41

# %% [markdown]
# Assign `a1b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a1b = best_score                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a1b = ${a1b:,.2f}")
# Out:
# a1b = $30,312.70

# %% [markdown]
# ## **Problem Two: Backward Selection with the Ames Dataset**
#
# Now, repeat the same process as in Problem One, but using the `backward_feature_selection` algorithm from this week’s video notebook. Again, we will use 5-Fold CV scoring.
#
# **Steps to Follow:**
# 1. **Observe** that we have provided the `backward_feature_selection` algorithm from this week's video notebook for you to use.
# 2. **Run** the backward selection algorithm on the Ames dataset (`X_train` and `y_train`).
# 3. **Plot** the results: Display the Root Mean Squared Error (RMSE) vs. the features removed by the algorithm.
# 4. **Print** the Best Feature Set found by backward selection and the corresponding best CV RMSE Score.

# %%
# Backward Feature Selection

def backward_feature_selection(X, y, model, 
                               scoring='neg_mean_squared_error', 
                               cv = 5, 
                               tol=None,               # None = no delta cutoff
                                                       # use 0.0 for "no further improvements"
                                                       # and 1e-4 for "point of diminishing returns"                                      
                               max_features=None,      # If None, remove features until only 1 remains
                                                       # Otherwise, stop when this many features remain
                               n_jobs=-1,
                               verbose=True
                              ):
    
    # Helper function to compute CV score using LinearRegression
    def cv_score(features):
        return np.sqrt(-cross_val_score(model, X[features], y, 
                                scoring=scoring, cv=cv, 
                                n_jobs=n_jobs          ).mean())
    
    # Start with all features (using a list for easier manipulation)
    features_remaining = list(X.columns)
    
    # Compute initial CV score with the full feature set
    initial_score = cv_score(features_remaining)
    
    # Initialize tracking variables
    best_score        = initial_score                # Best (lowest) CV score observed so far
    best_feature_set  = features_remaining.copy()    # Feature set corresponding to best_score
    selected_features = ['NONE']                     # List to record the order in which features are removed
    best_scores       = [initial_score]              # List to record the CV score after each removal (starting with full set)
    
    if verbose:
        print("Start with full set of features:")
        print(f'{features_remaining}  CV score (RMSE): {np.around(initial_score, 4)}\n')
    
    # Determine the target number of features to keep:
    # For backward elimination, if max_features is None, we remove until 1 feature remains.
    target_feature_count = 1 if max_features is None else max_features
    
    prev_score = initial_score
    round_num = 1
    # Continue removing features until we reach the target count
    while len(features_remaining) > target_feature_count:
        if verbose:
            print(f'Round {round_num}:')
            
        # Initialize variables to track the best removal in this round
        lowest_score = float('inf')
        feature_to_remove = None
        best_new_features = None
        
        # Try removing each feature one at a time
        for feature in features_remaining:
            new_feature_set = features_remaining.copy()
            new_feature_set.remove(feature)
            new_score = cv_score(new_feature_set)
            if verbose:
                print('Trying removal of:',feature, np.around(new_score, 4))
            if new_score < lowest_score:
                lowest_score = new_score
                feature_to_remove = feature
                best_new_features = new_feature_set
        
        # Check if improvement is significant enough (if tol is set)
        if tol is not None and (prev_score - lowest_score) < tol:
            if verbose:
                print("\nStopping early due to minimal improvement.")
            break
        
        # Update the best score and feature set if current removal improves performance
        if lowest_score < best_score:
            best_score = lowest_score
            best_feature_set = best_new_features.copy()
        
        # Update trackers for this round
        prev_score = lowest_score
        features_remaining = best_new_features
        selected_features.append(feature_to_remove)
        best_scores.append(lowest_score)
        
        if verbose:
            print(f'\nRemoving {feature_to_remove}:  CV score (RMSE) {np.around(lowest_score, 4)}\n')
        round_num += 1

    return (
        selected_features,      # Order in which features were removed
        best_scores,            # CV scores after each removal step
        best_feature_set,       # Feature set that achieved the best CV score
        best_score              # Best (lowest) CV score
    )

# %%
# Your code here:  Run Backward Feature Selection, plot the results, and print out the Best Feature Set and the Best CV RMSE Score found. 
model = LinearRegression()
selected_features, best_scores, best_feature_set, best_score = backward_feature_selection(
    X_train, y_train, model, verbose=True
)
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(best_scores) + 1), best_scores, marker='o')
plt.xlabel('Features Removed')
plt.ylabel('CV Score (RMSE)')
plt.title('Backward Feature Selection: CV Score vs. Number of Features Removed')
plt.grid()
plt.show()
print(f"Best Feature Set: {best_feature_set}")
print(f"Best CV Score (RMSE): {best_score:.4f}")
# Out:
# Start with full set of features:
# ['MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1', 'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF', 'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath', 'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr', 'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional', 'Fireplaces', 'Garage Type', 'Garage Yr Blt', 'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual', 'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF', 'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type', 'Sale Condition']  CV score (RMSE): 31485.4127
#
# Round 1:
# Trying removal of: MS SubClass 31556.4
# Trying removal of: MS Zoning 31488.6874
# Trying removal of: Lot Frontage 31420.4793
# Trying removal of: Lot Area 994194962634709.2
# Trying removal of: Street 31504.0608
# Trying removal of: Lot Shape 31500.5358
# Trying removal of: Land Contour 31503.055
# Trying removal of: Utilities 31451.8039
# Trying removal of: Lot Config 31472.1325
# Trying removal of: Land Slope 31504.2319
# Trying removal of: Neighborhood 31545.7036
# Trying removal of: Condition 1 31472.6887
# Trying removal of: Neighborhood 30636.2645
# Trying removal of: Overall Qual 32201.5368
# Trying removal of: Overall Cond 30882.1112
# Trying removal of: Year Built 30896.3598
# Trying removal of: Mas Vnr Area 30722.9261
# Trying removal of: Exter Qual 31036.6074
# Trying removal of: Bsmt Qual 30843.1854
# Trying removal of: Bsmt Exposure 30850.0554
# Trying removal of: BsmtFin Type 1 30674.2033
# Trying removal of: 1st Flr SF 33831.7108
# Trying removal of: 2nd Flr SF 34945.2203
# Trying removal of: Bsmt Full Bath 30916.1989
# Trying removal of: Kitchen AbvGr 30642.6658
# Trying removal of: Kitchen Qual 30887.3221
# Trying removal of: Functional 30702.8516
# Trying removal of: Fireplaces 30690.1057
# Trying removal of: Garage Cars 30842.3764
# Trying removal of: Screen Porch 30812.5135
# Trying removal of: Yr Sold 30639.8007
# Trying removal of: Sale Condition 30685.6134
#
# Removing Neighborhood:  CV score (RMSE) 30636.2645
#
# Round 53:
# Trying removal of: MS SubClass 31195.2314
# Trying removal of: Lot Area 30820.0094
# Trying removal of: Overall Qual 32318.9547
# Trying removal of: Overall Cond 30937.534
# Trying removal of: Year Built 30933.3798
# Trying removal of: Mas Vnr Area 30792.5113
# Trying removal of: Exter Qual 31117.0504
# Trying removal of: Bsmt Qual 30915.8908
# Trying removal of: Bsmt Exposure 30883.64
# Trying removal of: BsmtFin Type 1 30749.8877
# Trying removal of: 1st Flr SF 33924.0435
# Trying removal of: 2nd Flr SF 34972.246
# Trying removal of: Bsmt Full Bath 30985.8982
# Trying removal of: Kitchen AbvGr 30695.9531
# Trying removal of: Kitchen Qual 30950.3506
# Trying removal of: Functional 30767.626
# Trying removal of: Fireplaces 30737.4913
# Trying removal of: Garage Cars 30924.1599
# Trying removal of: Screen Porch 30873.5774
# Trying removal of: Yr Sold 30698.4821
# Trying removal of: Sale Condition 30743.7804
#
# Removing Kitchen AbvGr:  CV score (RMSE) 30695.9531
#
# Round 54:
# Trying removal of: MS SubClass 31457.8596
# Trying removal of: Lot Area 30887.3194
# Trying removal of: Overall Qual 32544.5689
# Trying removal of: Overall Cond 31014.8122
# Trying removal of: Year Built 31000.9133
# Trying removal of: Mas Vnr Area 30862.59
# Trying removal of: Exter Qual 31169.6396
# Trying removal of: Bsmt Qual 31002.5072
# Trying removal of: Bsmt Exposure 30956.2343
# Trying removal of: BsmtFin Type 1 30824.808
# Trying removal of: 1st Flr SF 34081.4811
# Trying removal of: 2nd Flr SF 34980.8122
# Trying removal of: Bsmt Full Bath 31036.7851
# Trying removal of: Kitchen Qual 31029.2787
# Trying removal of: Functional 30813.0283
# Trying removal of: Fireplaces 30824.5605
# Trying removal of: Garage Cars 30971.8463
# Trying removal of: Screen Porch 30947.1557
# Trying removal of: Yr Sold 30764.8815
# Trying removal of: Sale Condition 30805.7677
#
# Removing Yr Sold:  CV score (RMSE) 30764.8815
#
# Round 55:
# Trying removal of: MS SubClass 31512.8131
# Trying removal of: Lot Area 30960.324
# Trying removal of: Overall Qual 32608.1846
# Trying removal of: Fireplaces 31233.5104
# Trying removal of: Garage Cars 31389.7205
# Trying removal of: Screen Porch 31341.3638
#
# Removing Fireplaces:  CV score (RMSE) 31233.5104
#
# Round 59:
# Trying removal of: MS SubClass 32011.669
# Trying removal of: Lot Area 31478.634
# Trying removal of: Overall Qual 33522.19
# Trying removal of: Overall Cond 31726.883
# Trying removal of: Year Built 31723.5143
# Trying removal of: Mas Vnr Area 31461.9628
# Trying removal of: Exter Qual 31620.4829
# Trying removal of: Bsmt Qual 31495.4461
# Trying removal of: Bsmt Exposure 31551.328
# Trying removal of: 1st Flr SF 34969.8404
# Trying removal of: 2nd Flr SF 35732.233
# Trying removal of: Bsmt Full Bath 31890.6638
# Trying removal of: Kitchen Qual 31551.0384
# Trying removal of: Garage Cars 31538.6137
# Trying removal of: Screen Porch 31532.5807
#
# Removing Mas Vnr Area:  CV score (RMSE) 31461.9628
#
# Round 60:
# Trying removal of: MS SubClass 32223.9843
# Trying removal of: Lot Area 31697.419
# Trying removal of: Overall Qual 33861.4187
# Trying removal of: Overall Cond 31926.7542
# Trying removal of: Year Built 31985.8911
# Trying removal of: Exter Qual 31914.952
# Trying removal of: Bsmt Qual 31702.0666
# Trying removal of: Bsmt Exposure 31799.4315
# Trying removal of: 1st Flr SF 35826.2892
# Trying removal of: 2nd Flr SF 36283.3214
# Trying removal of: Bsmt Full Bath 32140.2016
# Trying removal of: Kitchen Qual 31755.9297
# Trying removal of: Garage Cars 31801.6305
# Trying removal of: Screen Porch 31782.1956
#
# Removing Lot Area:  CV score (RMSE) 31697.419
#
# Round 61:
# Trying removal of: MS SubClass 32594.0559
# Trying removal of: Overall Qual 33924.4881
# Trying removal of: Overall Cond 32156.3915
# Trying removal of: Year Built 32182.9405
# Trying removal of: Exter Qual 32132.4517
# Trying removal of: Bsmt Qual 31936.9319
# Trying removal of: Bsmt Exposure 32099.3366
# Trying removal of: 1st Flr SF 36768.7838
# Trying removal of: 2nd Flr SF 36805.8834
# Trying removal of: Bsmt Full Bath 32437.5101
# Trying removal of: Kitchen Qual 31965.1602
# Trying removal of: Garage Cars 32084.9604
# Trying removal of: Screen Porch 32010.3618
#
# Removing Bsmt Qual:  CV score (RMSE) 31936.9319
#
# Round 62:
# Trying removal of: MS SubClass 32806.6209
# Trying removal of: Overall Qual 34413.7759
# Trying removal of: Overall Cond 32328.3834
# Trying removal of: Year Built 32646.7872
# Trying removal of: Exter Qual 32565.9383
# Trying removal of: Bsmt Exposure 32413.7608
# Trying removal of: 1st Flr SF 36927.0761
# Trying removal of: 2nd Flr SF 37135.5497
# Trying removal of: Bsmt Full Bath 32726.3622
# Trying removal of: Kitchen Qual 32257.8855
# Trying removal of: Garage Cars 32392.367
# Trying removal of: Screen Porch 32227.085
#
# Removing Screen Porch:  CV score (RMSE) 32227.085
#
# Round 63:
# Trying removal of: MS SubClass 33136.6517
# Trying removal of: Overall Qual 34717.0068
# Trying removal of: Overall Cond 32628.9001
# Trying removal of: Year Built 32881.6606
# Trying removal of: Exter Qual 32825.8623
# Trying removal of: Bsmt Exposure 32706.2863
# Trying removal of: 1st Flr SF 37399.2952
# Trying removal of: 2nd Flr SF 37539.1369
# Trying removal of: Bsmt Full Bath 33062.7882
# Trying removal of: Kitchen Qual 32547.4891
# Trying removal of: Garage Cars 32683.4761
#
# Removing Kitchen Qual:  CV score (RMSE) 32547.4891
#
# Round 64:
# Trying removal of: MS SubClass 33514.1647
# Trying removal of: Overall Qual 35356.1337
# Trying removal of: Overall Cond 33002.4025
# Trying removal of: Year Built 33264.0414
# Trying removal of: Exter Qual 33847.312
# Trying removal of: Bsmt Exposure 33041.0719
# Trying removal of: 1st Flr SF 37772.2008
# Trying removal of: 2nd Flr SF 38041.9846
# Trying removal of: Bsmt Full Bath 33424.7354
# Trying removal of: Garage Cars 32999.0376
#
# Removing Garage Cars:  CV score (RMSE) 32999.0376
#
# Round 65:
# Trying removal of: MS SubClass 34097.1721
# Trying removal of: Overall Qual 36263.0542
# Trying removal of: Overall Cond 33426.8345
# Trying removal of: Year Built 34139.7357
# Trying removal of: Exter Qual 34326.9769
# Trying removal of: Bsmt Exposure 33540.2144
# Trying removal of: 1st Flr SF 39195.1295
# Trying removal of: 2nd Flr SF 39512.4748
# Trying removal of: Bsmt Full Bath 33921.7621
#
# Removing Overall Cond:  CV score (RMSE) 33426.8345
#
# Round 66:
# Trying removal of: MS SubClass 34649.8163
# Trying removal of: Overall Qual 37415.1564
# Trying removal of: Year Built 34186.2832
# Trying removal of: Exter Qual 34656.1056
# Trying removal of: Bsmt Exposure 33986.6395
# Trying removal of: 1st Flr SF 39201.1717
# Trying removal of: 2nd Flr SF 39703.1737
# Trying removal of: Bsmt Full Bath 34396.4853
#
# Removing Bsmt Exposure:  CV score (RMSE) 33986.6395
#
# Round 67:
# Trying removal of: MS SubClass 34990.4852
# Trying removal of: Overall Qual 38166.6582
# Trying removal of: Year Built 34927.357
# Trying removal of: Exter Qual 35229.0099
# Trying removal of: 1st Flr SF 39886.788
# Trying removal of: 2nd Flr SF 39807.4694
# Trying removal of: Bsmt Full Bath 35243.9055
#
# Removing Year Built:  CV score (RMSE) 34927.357
#
# Round 68:
# Trying removal of: MS SubClass 35823.89
# Trying removal of: Overall Qual 41674.605
# Trying removal of: Exter Qual 36598.4215
# Trying removal of: 1st Flr SF 40388.7089
# Trying removal of: 2nd Flr SF 40033.976
# Trying removal of: Bsmt Full Bath 36463.6969
#
# Removing MS SubClass:  CV score (RMSE) 35823.89
#
# Round 69:
# Trying removal of: Overall Qual 42199.0806
# Trying removal of: Exter Qual 37373.2374
# Trying removal of: 1st Flr SF 42354.6054
# Trying removal of: 2nd Flr SF 40173.688
# Trying removal of: Bsmt Full Bath 37090.5794
#
# Removing Bsmt Full Bath:  CV score (RMSE) 37090.5794
#
# Round 70:
# Trying removal of: Overall Qual 43758.3154
# Trying removal of: Exter Qual 38636.8058
# Trying removal of: 1st Flr SF 44212.777
# Trying removal of: 2nd Flr SF 40750.1423
#
# Removing Exter Qual:  CV score (RMSE) 38636.8058
#
# Round 71:
# Trying removal of: Overall Qual 51320.7941
# Trying removal of: 1st Flr SF 46286.2359
# Trying removal of: 2nd Flr SF 42141.9873
#
# Removing 2nd Flr SF:  CV score (RMSE) 42141.9873
#
# Round 72:
# Trying removal of: Overall Qual 61456.6742
# Trying removal of: 1st Flr SF 46802.2075
#
# Removing 1st Flr SF:  CV score (RMSE) 46802.2075
# Best Feature Set: ['MS SubClass', 'Lot Area', 'Street', 'Lot Shape', 'Land Contour', 'Land Slope', 'Neighborhood', 'Bldg Type', 'House Style', 'Overall Qual', 'Overall Cond', 'Year Built', 'Roof Style', 'Exterior 1st', 'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Bsmt Qual', 'Bsmt Exposure', 'BsmtFin Type 1', 'Bsmt Unf SF', 'Heating QC', '1st Flr SF', '2nd Flr SF', 'Low Qual Fin SF', 'Bsmt Full Bath', 'Half Bath', 'Kitchen AbvGr', 'Kitchen Qual', 'Functional', 'Fireplaces', 'Garage Yr Blt', 'Garage Cars', 'Garage Qual', 'Garage Cond', 'Wood Deck SF', 'Enclosed Porch', 'Screen Porch', 'Yr Sold', 'Sale Condition']
# Best CV Score (RMSE): 30232.6220

# %% [markdown]
# ### Problem Two Graded Questions
#
# Assign `a2a` to the number of features in the best feature set found

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2a = len(best_feature_set)                   # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2a = {a2a}")
# Out:
# a2a = 40

# %% [markdown]
# Assign `a2b` to the best CV RMSE score found.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a2b = best_score                     # replace 0 with an expression

# %%
# Do not change this cell in any way

print(f"a2b = ${a2b:,.2f}")
# Out:
# a2b = $30,232.62

# %% [markdown]
# ## **Problem Three: Ridge Regression on the Ames Housing Dataset**
#
# In this problem, we will apply Ridge Regression to the Ames Housing dataset. Ridge Regression includes a hyperparameter $\alpha$ that controls the strength of the regularization penalty, which helps prevent overfitting by constraining the growth of the model’s coefficients. A higher $\alpha$ penalizes large coefficients more, while a lower $\alpha$ allows them to grow larger.
#
# When creating the model, the parameter must be specified, for example:
#
# ```python
# ridge_model = Ridge(alpha=100)
# ```
#
# This introduces another instance of the model selection problem: we must determine the value of $\alpha$ that yields the best CV RMSE score.
#
# **Steps to Follow:**
#
# 1. **Standardize the Data:**
#    Ridge regression is sensitive to the scale of the features, so we will use `StandardScaler` to standardize the feature set to have a mean of 0 and a standard deviation of 1 before training and testing. Note that the target variable does **not** need to be scaled.
#
# 2. **Perform Cross-Validation Over a Range of Alpha Values:**
#    For each $\alpha \in \{100, 110, 120, \dots, 500\}$, calculate the cross-validation RMSE score for the model using 5-Fold CV scoring.
#
# 3. **Visualize the Results:**
#    Plot the CV RMSE scores against the $\alpha$ values.
#
# 4. **Identify the Best Alpha:**
#    Determine the $\alpha$ that results in the minimum CV RMSE Score and print it out, along with the score.
#
# **Tip:** It would be an *excellent* idea to add the suffix `_scaled` to any set to which you apply scaling.

# %%
# Your code here
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
alphas = np.logspace(-3, 3, 13)
ridge_scores = []

for alpha in alphas:
    ridge_model = Ridge(alpha=alpha)
    rmse = np.sqrt(-cross_val_score(ridge_model, X_train_scaled, y_train, scoring='neg_mean_squared_error', cv=5).mean())
    ridge_scores.append(rmse)

plt.figure(figsize=(10, 6))
plt.plot(alphas, ridge_scores, marker='o')
plt.xscale('log')
plt.xlabel('Alpha (log scale)')
plt.ylabel('CV Score (RMSE)')
plt.title('Ridge Regression: CV Score vs. Alpha')
plt.grid()
plt.show()

# %% [markdown]
# ### Problem Three Graded Answers
#
# Set `a3a` to the alpha determined to have the minimum CV RMSE score.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3a = alphas[np.argmin(ridge_scores)]                     # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3a = {a3a}")
# Out:
# a3a = 316.22776601683796

# %% [markdown]
# Set `a3b` to the CV score found at that alpha.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a3b = np.min(ridge_scores)                     # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a3b = ${a3b:,.2f}")
# Out:
# a3b = $31,154.80

# %% [markdown]
# ## **Problem Four: Evaluate Your Best Model**
#
# In this final problem, you will identify the model with the best cross-validation RMSE score and evaluate its performance on the held-out test set.
#
# #### **Steps to Follow:**
#
# 1. **Identify the Best Model:**
#    From your previous results, select the model that achieved the lowest CV RMSE score.
#
# 3. **Train and Test the Selected Model:**
#    - For Forward or Backward Feature Selection:  Train a Linear Regression model using `X_train` **restricted to the selected best feature set**, and evaluate it on `X_test` restricted to the same feature set.
#    - For Ridge Regression:   Train a Ridge Regression model using the best alpha found from cross-validation, with `StandardScaler` applied to both `X_train` and `X_test` before training and testing.
#
# 4. **Report Your Results:**
#    Print the name of the best model and the test RMSE in dollars.

# %%
# Your code here
eval_model = LinearRegression()
eval_model.fit(X_train[best_feature_set], y_train)
y_pred = eval_model.predict(X_test[best_feature_set])
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
test_r2 = r2_score(y_test, y_pred)
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test R^2: {test_r2:.4f}")
# Out:
# Test RMSE: 33581.5644
# Test R^2: 0.8593

# %% [markdown]
# ### Problem Four Graded Answers
#
# Set `a4a` to the best model, according to the CV RMSE score.
#
# - 1 = Forward Selection
# - 2 = Backward Selection
# - 3 = Ridge Regression

# %%
# Your answer here

a4a = 2                     # replace 0 with one of [1,2,3]

# %%
# Do not change this cell in any way. 

print(f"a4a = {a4a}")
# Out:
# a4a = 2

# %% [markdown]
# Set `a4b` to the test RMSE for the best model.

# %%
# Your answer here; use an expression, not a constant derived by examining the data

a4b = test_rmse                    # replace 0 with an expression

# %%
# Do not change this cell in any way. 

print(f"a4b = ${a4b:,.2f}")
# Out:
# a4b = $33,581.56

# %% [markdown]
# ### Appendix: Final "Pause and Ponder" issue (ungraded) ....
#
# Why didn't we evaluate *all* the models on the test set and compare them?
#
# ### Some answers...
#
# It’s tempting to reconsider your choice based on test scores, but this violates the core principle of not "training to the test." That’s why we deliberately avoided evaluating all models on the test set.
#
# The test set doesn’t influence model training; it serves as a final, unbiased check on how well your chosen model generalizes to unseen data, ensuring that your selection process wasn’t overly optimistic.
#
# A natural **next question** is: Why use a test set at all? Beyond being an industry-standard practice that simulates the real world—where you can’t adjust your model after deployment—consider:
#
# - **Validating your workflow:** A strong test score confirms that your model selection process (feature selection, hyperparameter tuning, etc.) was sound. A poor test score despite good cross-validation results may indicate overfitting or a flawed approach.
#
# - **Guarding against over-optimism:** Cross-validation can be slightly optimistic, especially with limited data or repeated trials. The test set provides a final safeguard against relying on an overly tuned model.
